# %%
import kagglehub
import os, glob

path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
print("Downloaded to:", path)
print("Files:", glob.glob(os.path.join(path, "*")))
# Out:
# Downloaded to: /Users/tanujih/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3
# Files: ['/Users/tanujih/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3/creditcard.csv']

# %%
import os
import glob

data_path = "/Users/tanujih/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/1"

files = glob.glob(os.path.join(data_path, "*"))
files
# Out:
# []

# %%
import kagglehub

path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
print(path)
# Out:
# /Users/tanujih/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3

# %%
import os, glob

files = glob.glob(os.path.join(path, "**", "*"), recursive=True)
files
# Out:
# ['/Users/tanujih/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3/creditcard.csv']

# %%
import pandas as pd

csv_path = [f for f in files if f.endswith(".csv")][0]
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df['Class'].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
X = df.drop(columns=['Class'])
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

num_features = ['Amount', 'Time']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features)
    ],
    remainder='passthrough'
)

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('clf', LogisticRegression(max_iter=1000))
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['Amount', 'Time'])])),
#                 ('clf', LogisticRegression(max_iter=1000))])

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[56851    13]
#  [   35    63]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
y_probs = model.predict_proba(X_test)[:, 1]

# %%
import pandas as pd
pd.Series(y_probs).head(10)
# Out:
# 0    0.000090
# 1    0.000031
# 2    0.000008
# 3    0.000130
# 4    0.008138
# 5    0.000278
# 6    0.000030
# 7    0.000157
# 8    0.000793
# 9    0.000022
# dtype: float64

# %%
pd.Series(y_probs).describe()
# Out:
# count    5.696200e+04
# mean     1.858026e-03
# std      3.537540e-02
# min      1.020861e-10
# 25%      6.237438e-05
# 50%      1.643418e-04
# 75%      3.990543e-04
# max      1.000000e+00
# dtype: float64

# %%
import numpy as np
from sklearn.metrics import classification_report

for threshold in [0.5, 0.3, 0.25, 0.2]:
    y_pred_thresh = (y_probs >= threshold).astype(int)
    print(f"\nThreshold: {threshold}")
    print(classification_report(y_test, y_pred_thresh))
# Out:
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.73      0.68      0.71        98
#
#     accuracy                           1.00     56962
#    macro avg       0.86      0.84      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.25
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.73      0.70      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.85      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.2
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.74      0.74      0.74        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.87      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_probs)
# Out:
# 0.9558983554029378

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight="balanced",
    n_jobs=-1
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %%
y_probs_rf = rf.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import classification_report

for threshold in [0.5, 0.3, 0.25, 0.2]:
    y_pred_thresh = (y_probs_rf >= threshold).astype(int)
    print(f"\nThreshold: {threshold}")
    print(classification_report(y_test, y_pred_thresh))
# Out:
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.76      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.84      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.25
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.88      0.85      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.92      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Threshold: 0.2
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.85      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.92      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_thresh)
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
